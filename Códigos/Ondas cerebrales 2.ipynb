# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from numpy.fft import fft,rfft
from scipy.signal import spectrogram

# %%
t = np.linspace(0,1,1000)
x = np.cos(2*np.pi*10*t)
plt.figure(figsize=(12,3))
plt.plot(t,x)

fj = 4
fj_sen = np.sin(-2*np.pi*fj*t)
fj_cos = np.cos(-2*np.pi*fj*t)

plt.figure(figsize=(12,3))
plt.plot(t,x,color='blue',label='Original')
plt.plot(t,fj_sen,color='red',label='Seno',linestyle='--')
plt.plot(t,fj_sen,color='red',label='Coseno',linestyle=':')
plt.legend()
plt.xlabel()

# %%
fj = 4
fj_sen = np.sin(-2*np.pi*fj*t)
fj_cos = np.cos(-2*np.pi*fj*t)

plt.figure(figsize=(12,3))
plt.plot(t,x,color='blue',label='Original')
plt.plot(t,fj_sen,color='red',label='Seno',linestyle='--')
plt.plot(t,fj_cos,color='green',label='Coseno',linestyle=':')
plt.legend()
